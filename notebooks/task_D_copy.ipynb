# %%
import sys
sys.path.append('../')

import torch
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from torch.optim.lr_scheduler import StepLR
import torch.nn as nn
from tqdm.notebook import tqdm

from src.data import (
    TrainDataset,
    train_collate_fn,
    InferenceDataset,
    inference_collate_fn,
    get_item_list,
    get_item_labels,
    get_pair_list,
    read_words_from_file,
)
from src.models import ( 
    single_model,
    train_model_early_stopping,
    BERT52,
    AttnLSTM52,
    AttnBiLSTM52, 
    LSTMBERT52,
)
from settings import BATCH_SIZE

# %%
train_file_path = "../data/raw/train_stresses_labels.txt"
public_file_path = "../data/raw/public_test_stresses.txt"

# %%
with open(train_file_path, "r", encoding='utf-8') as file:
    words = file.read().splitlines()

# %%
words[:10]
# Out:
# ['аа^к',
#  'аа^ка',
#  'аа^ке',
#  'аа^ки',
#  'аа^ков',
#  'аа^ком',
#  'аа^м',
#  'аа^му',
#  'аа^нгича',
#  'аа^нгичам']

# %%
train_words, val_words = [words[i] for i in range(len(words)) if i % 100 != 0], [words[i] for i in range(len(words)) if i % 100 == 0]

# %%
len(train_words), len(val_words)
# Out:
# (582605, 5885)

# %%
'sdfsd^f'.replace('^', '')
# Out:
# 'sdfsdf'

# %%
train_dataset = TrainDataset(train_words, tokenizer=get_item_list)
train_loader = DataLoader(train_dataset, batch_size=2048, shuffle=True, collate_fn=train_collate_fn)

val_dataset = TrainDataset(val_words, tokenizer=get_item_list)
val_loader = DataLoader(val_dataset, batch_size=2048, shuffle=True, collate_fn=train_collate_fn)

# %%
model52 = AttnBiLSTM52()
optimizer = AdamW(model52.parameters(), lr=5e-3)
scheduler = StepLR(optimizer, step_size=10, gamma=0.2)

# %%
params_count = sum(p.numel() for p in model52.parameters() if p.requires_grad)

print(f'Number of trainable parameters: {params_count}')
# Out:
# Number of trainable parameters: 1160847

# %%
early_stopping = True

if early_stopping:
    model52 = train_model_early_stopping(
        model=model52,
        train_loader=train_loader,
        val_loader=val_loader,
        optimizer=optimizer,
        scheduler=scheduler,
        device=torch.device('cuda'),#torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
        loss_function=nn.CrossEntropyLoss(),
    )
    
else:
    single_model(
        model=model52,
        train_loader=train_loader,
        val_loader=val_loader,
        optimizer=optimizer,
        scheduler=scheduler,
        device=torch.device('cuda'),#torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
        loss_function=nn.CrossEntropyLoss(),
        epochs=12
    )
# Out:
#   0%|          | 0/285 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 4
#       1 early_stopping = True
#       3 if early_stopping:
# ----> 4     model52 = train_model_early_stopping(
#       5         model=model52,
#       6         train_loader=train_loader,
#       7         val_loader=val_loader,
#       8         optimizer=optimizer,
#       9         scheduler=scheduler,
#      10         device=torch.device('cuda'),#torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
#      11         loss_function=nn.CrossEntropyLoss(),
#      12     )
#      14 else:
#      15     single_model(
#      16         model=model52,
#      17         train_loader=train_loader,
#    (...)
#      23         epochs=12
#      24     )
#
# File ~\PycharmProjects\blyat\rucode_7.0\notebooks\..\src\models\train_model.py:117, in train_model_early_stopping(model, train_loader, val_loader, loss_function, optimizer, scheduler, device, early_stopping, eps)
#     115 epoch = 0
#     116 while es > 0:
# --> 117     train_metrics = train_epoch(
#     118         model, train_loader, loss_function, optimizer, scheduler, device
#     119     )
#     120     eval_metrics = eval_epoch(model, val_loader, loss_function, device)
#     121     epoch += 1
#
# File ~\PycharmProjects\blyat\rucode_7.0\notebooks\..\src\models\train_model.py:29, in train_epoch(model, data_loader, loss_function, optimizer, scheduler, device)
#      26     batch[key] = batch[key].to(device)
#      28 optimizer.zero_grad()
# ---> 29 logits = model(batch)
#      31 preds.append(logits.argmax(dim=1))
#      32 targets.append(batch["labels"])
#
# File c:\users\даня\appdata\local\programs\python\python38\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\PycharmProjects\blyat\rucode_7.0\notebooks\..\src\models\AttnBiLSTM52.py:48, in AttnBiLSTM52.forward(self, batch)
#      44 mask = torch.ones(seq.size()[0], 1, seq.size()[1], seq.size()[1]).to(
#      45     self.device
#      46 )
#      47 mask[:, :, -1, :] = 0
# ---> 48 attn_out = self.attention(output, mask)
#      49 logits = self.classifier(attn_out[:, -1, :])
#      50 return logits
#
# File c:\users\даня\appdata\local\programs\python\python38\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\PycharmProjects\blyat\rucode_7.0\notebooks\..\src\models\transformer.py:29, in TransformerBlock.forward(self, x, mask)
#      28 def forward(self, x, mask):
# ---> 29     x = self.input_sublayer(x, lambda _x: self.attention.forward(_x, _x, _x, mask=mask))
#      30     x = self.output_sublayer(x, self.feed_forward)
#      31     return self.dropout(x)
#
# File c:\users\даня\appdata\local\programs\python\python38\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\PycharmProjects\blyat\rucode_7.0\notebooks\..\src\models\utils\sublayer.py:18, in SublayerConnection.forward(self, x, sublayer)
#      16 def forward(self, x, sublayer):
#      17     "Apply residual connection to any sublayer with the same size."
# ---> 18     return x + self.dropout(sublayer(self.norm(x)))
#
# File c:\users\даня\appdata\local\programs\python\python38\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\PycharmProjects\blyat\rucode_7.0\notebooks\..\src\models\utils\layer_norm.py:17, in LayerNorm.forward(self, x)
#      15 mean = x.mean(-1, keepdim=True)
#      16 std = x.std(-1, keepdim=True)
# ---> 17 return self.a_2 * (x - mean) / (std + self.eps) + self.b_2
#
# RuntimeError: The size of tensor a (128) must match the size of tensor b (256) at non-singleton dimension 2

# %%
with open(public_file_path, "r", encoding='utf-8') as file:
    test_words = file.read().splitlines()

# %%
test_dataset = InferenceDataset(test_words, tokenizer=get_item_list)
preds = []
test_loader = DataLoader(test_dataset, batch_size=4096, collate_fn=inference_collate_fn)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model52.to(device)
model52.eval()
total_train_loss = 0

preds = []
targets = []

dl_size = len(test_loader)


for batch in tqdm(test_loader):
    for key in batch:
        batch[key] = batch[key].to(device)

    with torch.no_grad():
        logits = model52(batch)
        preds.append(logits.argmax(dim=1))
preds = torch.cat(preds, dim=0)
# Out:
#   0%|          | 0/72 [00:00<?, ?it/s]

# %%
def insert_carot_after_vowel(w, k):
    vowels = ['а', 'е', 'ё', 'и', 'о', 'у', 'ы', 'э', 'ю', 'я']
    count = 0
    w1 = ""

    for char in w:
        w1 += char

        if char.lower() in vowels:
            count += 1
            if count == k:
                w1 += "^"

    return w1

# %%
sub = []
for idx, word in tqdm(enumerate(test_words)):
    stress_idx = preds[idx].item()
    sub.append(insert_carot_after_vowel(word, stress_idx))
# Out:
# 0it [00:00, ?it/s]

# %%
print(test_words[52])
print(sub[52])
# Out:
# абазой
# аба^зой

# %%
def write_to_file(sub, path):
    with open(path, "w", encoding='utf-8') as file:
        for word in sub:
            file.write(word + "\n")

# %%
write_to_file(sub, r"subm_ATTN_one_word_10layers_1.txt")
